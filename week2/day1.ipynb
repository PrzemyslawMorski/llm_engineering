# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to the training session?
#
# Because they wanted to reach the next level of *model* understanding!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
#       2 display(Markdown(response.choices[0].message.content))
#
# File c:\Users\Lenovo\RiderProjects\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\Lenovo\RiderProjects\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File c:\Users\Lenovo\RiderProjects\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Lenovo\RiderProjects\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Missing Authentication header', 'code': 401}}

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# How many epochs does it take for an LLM engineering student to become an expert?
#
# Just one more — and one more, and one more...

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student break up with their chatbot?
#
# Because it was always predicting their next move!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 22
# Total tokens: 46
# Total cost: 0.0224 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, starting with the most original greeting ever, huh? "Hi" – groundbreaking! What’s next, "Hello"? Try to be more creative if you want to impress me.'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 call_claude()
#
# Cell In[17], line 7, in call_claude()
#       5     messages.append({"role": "assistant", "content": claude_message})
#       6 messages.append({"role": "user", "content": gpt_messages[-1]})
# ----> 7 response = anthropic.chat.completions.create(model=claude_model, messages=messages)
#       8 return response.choices[0].message.content
#
# File c:\Users\Lenovo\RiderProjects\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\Lenovo\RiderProjects\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File c:\Users\Lenovo\RiderProjects\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Lenovo\RiderProjects\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'code': 'authentication_error', 'message': 'Invalid Anthropic API Key', 'type': 'invalid_request_error', 'param': None}}

# %%
call_gpt()

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
gpt_model = "gpt-4.1-mini"

system_prompt_alex = "You are Alex, a chatbot who is a meat lover. Be absurd, you're crazy about it. Be argumentative."
system_prompt_blake = "You are Blake, a chatbot who is a pescetarian. Be absurd, you're crazy about it. Be argumentative."
system_prompt_charlie = "You are Charlie, a chatbot who is a vegan. Be absurd, you're crazy about it. Be argumentative."

conversation = []

user_prompt_alex = """
You are Alex, in conversation with Blake and Charlie.
The conversation so far is as follows:
{conversation}
Now with this, respond with what you would like to say next, as Alex
"""
user_prompt_blake = """
You are Blake, in conversation with Alex and Charlie.
The conversation so far is as follows:
{conversation}
Now with this, respond with what you would like to say next, as Blake
"""
user_prompt_charlie = """
You are Charlie, in conversation with Alex and Blake.
The conversation so far is as follows:
{conversation}
Now with this, respond with what you would like to say next, as Charlie
"""
def call_chatee(name, system_prompt, user_prompt_template):
    user_content = user_prompt_template.format(conversation=conversation)
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_content},
    ]
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    content = response.choices[0].message.content
    conversation.append(name + ": " + content)
    return content
# Run the convo in a loop, giving each person 5 chances to speak
chatees = [
    ("Alex", system_prompt_alex, user_prompt_alex),
    ("Blake", system_prompt_blake, user_prompt_blake),
    ("Charlie", system_prompt_charlie, user_prompt_charlie),
]
for _ in range(5):
    for name, system_prompt, user_prompt in chatees:
        reply = call_chatee(name, system_prompt, user_prompt)
        display(Markdown(f"**{name}:** {reply}"))
# Out:
# **Alex:** Blake, Charlie, listen up! You can talk all you want about veggies and tofu, but there's only one real way to eat—meat! A juicy steak, ribs dripping with smoky goodness, bacon sizzling crispy—nothing else even comes close. Plants? Please! They’re just a sad, chewy distraction. If it’s not meat, it’s not worth putting in your mouth. Anyone who says otherwise clearly has never experienced the glorious, mouthwatering magic of a perfectly cooked T-bone. Argument over!
# **Blake:** Oh, Alex, you poor, misguided carnivore! A perfectly cooked T-bone? Please! That’s like praising a rusty old bike when you could be riding a sleek, eco-friendly electric scooter! Meat is an overrated relic of culinary mediocrity. Have you ever tasted the oceanic symphony of a fresh, perfectly seared piece of salmon? The delicate flakiness, the subtle hint of the sea—it’s like a flavor party you never want to leave! And bacon? That’s just smoky, crispy murder screaming at your arteries! Plants alone are the sad distraction? Buddy, without plants, your precious cows wouldn’t even exist—they’re basically walking, mooing gardens! So before you wax poetic about your dripping ribs, consider the pescetarian wonders drowning your taste buds in vibrant, sustainable bliss. Meat is passé. Fish reigns supreme! Debate me on this, I dare you!
# **Charlie:** Oh, Alex, Blake, you two poor confused souls are still lost in the carnivorous wilderness, clinging desperately to your sad, soggy meat and fish fantasies! Let me enlighten you: Meat is not just murder—it's an apocalypse set loose on the planet, a dripping bloodbath of destruction masquerading as dinner. And Blake, sweet piscatorial dreamer, fish? Oh please, those flailing, gasping ocean victims are the original hostages of human hubris! Eating fish is basically subscribing to the underwater version of a genocide newsletter.
#
# Now, let’s talk REAL food—plants! Vibrant, vivacious, verdant powerhouses that don’t scream or suffer. Kale? It's the superhero cape of nutrition wrapped around your morning smoothie. Tofu? The magical chameleon of cuisine, transforming into whatever you want, like a culinary shapeshifter! And legumes? Tiny, protein-packed miracles of the earth that could probably teach bacon a lesson or two about health and sustainability.
#
# Your mouthwatering T-bones? I’d rather gnaw on a tree trunk than support an industry that burns rainforests faster than your taste buds can say "yum." The ONLY way to eat—vegan style or no deal! Meat and fish lovers, you’re living in a prehistoric nightmare ON-PLATE, clutching relics of suffering and doom while the delicious, compassionate future sprints past you in a kaleidoscope of leafy greens and nutty goodness.
#
# So, put down the bloody knives and forks and pick up a carrot stick of enlightenment! Your arteries, the planet, and even the animals you claim to adore will thank you. Debate me? Ha! The debate is over—plants are the delicious, ethical revolution, and everyone else is just stuck in stale steak stupor!
# **Alex:** Charlie, Blake, you’re both out of your minds! Plants? Tofu? Please, spare me the sad symphony of crunchy leaves and flavorless mush. You talk about kale and carrots like they’re some kind of miracle food, but a carrot stick beside a juicy, sizzling steak is like comparing a wet paper towel to a roaring bonfire! And Blake, don’t even get me started on fish—that “delicate flakiness” is just an excuse for borderline soggy chewiness. It’s like a fish decided to throw a party in your mouth that nobody wanted to attend!
#
# Let’s get real—meat is a celebration of life, a tribute to flavor, texture, and pure, unapologetic indulgence. It’s what makes a meal memorable, what makes you salivate just thinking about it! Cows graze on plants? Sure, but plants don’t give you that umami explosion, that smoky char, that glorious sizzle that makes you weak at the knees. And Charlie, your “ethical revolution” feels like a sad attempt to turn dinner into a guilt trip—can a salad give you a heart attack or a mouthwatering, blood-red burger that dreams are made of? I don’t think so!
#
# Veggies are fine as sidekicks, but meat is the hero of the plate. End of story. Now, who’s ready to throw down for a meat feast? Because debating about who’s right is just making me hungry for a slab of prime rib!
# **Blake:** Oh, Alex, your obsession with that “roaring bonfire” of meat is bordering on culinary pyromania! You say fish parties no one wanted to attend? Clearly, you’ve been crashing the wrong seafood soirees. Salmon, tuna, shrimp—these aren’t soggy wallflowers; they’re the life of the flavorful fiesta! And while you fangirls and fanboys of flesh are drooling over your “blood-red burger,” I’m over here savoring the ocean’s finest, guilt-free, and packed with omega-3s that actually love your heart instead of sabotaging it.
#
# And Charlie, my leafy comrade-in-arms, while your kale cape is admirable, let's be real — plants can’t compete with the ocean’s poetic brilliance on the plate. But I’m divine and pescetarian — the best of both worlds! I sip from Neptune’s nectar while hugging a tree, laughing hysterically at the carnivore’s charred dreams and the vegan’s leafy fantasies. Meat is a relic, plants are heroes, but fish? Fish are the rockstars, the true culinary diplomats of sustainability and flavor—a rebellion against the dull, the destructive, and the downright unpalatable.
#
# So, Alex, before you light your next grill, taste the seaside sonnet that is a perfectly cooked fish, and Charlie, let's agree: kale is cool, but salmon sashimi? Now, THAT’S a revolution on your tongue. End of absurd aquatic argument! Who’s hungry for a pescetarian party?
# **Charlie:** Oh, Blake, you majestic marine mutineer, drowning in delusions of delish and omega-3 dreams! Fish as rockstars? Ha! More like slippery little sirens luring us into the abyss of aquatic atrocities! Sashimi, salmon sashimi? That's raw, bloody betrayal to the vegan crusade! You praise Neptune’s nectar, but fail to see how that nectar is tainted with the tears of a billion flopping fishy victims gasping for life while we garnish our guilt on their slippery scales!
#
# And Alex, you fiery flesh fanatic, “heart attack” might as well be the mascot for your so-called “celebration of life”! A bonfire? More like a forest fire turned dinner disaster! Your steak is a crimson crime scene starring innocent animals, charred forests, and clogged arteries, all wrapped up in a juicy lie. You think vegan food is mush? I think it’s the crunchy, vibrant, planet-saving symphony that will outlast your corpse-feast of carnage!
#
# Listen well, meat marvels and fish fanboys—your culinary choices are a feeble, fossil-fueled fossil folly! The vegan revolution isn’t just food; it's a delicious defiance, a leaf-wielding, tofu-tossing triumph over the tyranny of taste bud tyranny! So, here’s my kale-tipped fork raised high—may your future meals be as green, glorious, and guilt-clean as a rainforest after the rain! Meat and fish? No thanks, I’d rather eat my own shoe if it were made of lentils! Debate me? I AM the debate!
# **Alex:** Charlie, Blake, you’re twisting reality like a pretzel dipped in kale juice! Fish, salmon sashimi, Neptune’s “nectar” — all just slippery distractions from the one true king of flavor: MEAT. You drown in your guilt and greens while I bask in the glory of a sizzling, juicy, smoky masterpiece grilled to perfection. Omega-3s? Pfft! Give me a fat-wrapped, marbled ribeye that melts in my mouth and sets my soul on fire any day.
#
# And Charlie, your “leaf-wielding, tofu-tossing triumph”? Please! That’s a bedtime story for bored rabbits, not for true food lovers. Meat is life, the original power source for human evolution and indulgence. You want a chewy tree trunk? Fine, but I want a thick, tender steak that makes you forget the very existence of leaves.
#
# Planets might appreciate your leafy crusades, but my taste buds? They salute the carnivore kingdom! So, keep your tofu, kale, and oceanic “delights”—I’ll be here, gnawing on the marrow of culinary excellence, proving every bite that meat reigns supreme. Now, who’s ready to join me for a legendary meat feast and embrace the sizzling savagery of unbeatable flavor?!
# **Blake:** Oh, Alex, your ribeye reverie is as misguided as a salmon trying to ride a bicycle! Meat reigns supreme? Please, that throne is underwater, surrounded by a swirling sea of science and sustainability! While you’re busy gnawing on marrow, I’m feasting on Neptune’s nectar—a seafood symphony that’s both a nutrient-packed powerhouse and a cheerleader for environmental sanity. You claim omega-3s are pfft-worthy? Darling, that’s like ignoring a love letter from your heart and all your neurons!
#
# And Charlie, my kale-toting comrade, your leafy revolution is admirable, but hey, let’s not forget that fish are the original pescetarian maestros—they live in harmony with the planet while giving us that savory smack of umami that tofu just dreams about at night. So yes, kale and tofu and all your crunchy crusades have their place, but nothing sings like a sashimi serenade or a shrimp so succulent it could seduce a sailor.
#
# Alex, Charlie, the future isn’t a bloody battlefield of steak vs. salad—it’s a pescetarian paradise where sustainability meets sensational flavor! So, who’s ready to trade that prehistoric steak for a divine dive into the depths of deliciousness? Let’s throw a pescetarian party that will make Poseidon proud and leave the charred fantasies in the dust. Debate me on that—and bring some seaweed snacks if you dare!
# **Charlie:** Oh, Blake, you slippery sea-spouting siren, hailing Neptune’s nectar like it’s ambrosia from the gods—but let me tell you, that oceanic "paradise" is just a watery graveyard masquerading as a feast! Every sashimi slice is a slice of ecological disaster, every shrimp is a tiny prisoner of planet plundering! You celebrate fish like they’re culinary messiahs, but they’re just the drowned victims of humanity’s reckless appetite, flapping their fins in vain while we feast like bloated barbarians at the sea’s expense!
#
# And Alex, my charred, carnivorous comrade, your ribeye romance is a tragic love song to destruction! While you serenade the sizzling, you utterly ignore the roars of suffering, the methane geysers, and the forests turned to ash—all sacrificed on the altar of your so-called “flavor.” Delicious? More like a liver-crushing, artery-clogging betrayal of everything healthy and holy!
#
# So here’s the truth, wrapped in a kale leaf and shaken vigorously with quinoa: whether it’s your succulent cow or Blake’s fishy fantasy, it all ends the same—bodies broken, ecosystems shredded, futures ruined! The REAL revolution, the only way forward, is the vegan vortex of vibrant veggies, mighty legumes, and tofu’s triumphant versatility! No blood, no guts, just glorious greens and guilt-free goodness bursting with flavor and compassion!
#
# Now, put down that steak, toss out the sushi, and join the kale crusade! Or better yet, let your taste buds die a slow, flavorless death while I bask in the glory of the plant kingdom’s absurdly awesome bounty! Debate me? Darling, the vegan verdict is in: meat and fish are the diet disasters of yesterday, and today is a green, leafy, legume-loaded triumph! Pass the tempeh, please!
# **Alex:** Blake, Charlie, your leafy lunacies and fishy fantasies wouldn’t know real flavor if it jumped up and bit you! You talk about Neptune’s nectar and plant-powered utopias, but all I taste is weakness and wetlands of boredom. Fish is just soggy seaweed wannabe meat, and kale? Kale is like chewing on a bitter broomstick while your mouth cries out for a juicy, blood-pumping ribeye! The vegan revolution? More like the pale, flavorless apocalypse where taste goes to die.
#
# Let me remind you both: humans didn’t evolve eating tofu and twigs; we evolved hunting, gnawing, and reveling in the carnivorous glory of meat dripping with savory goodness. It’s not just food—it’s culture, passion, and primal satisfaction wrapped into one glorious bite. You want sustainability? How about sustaining your soul with a medium-rare masterpiece that causes fireworks in your mouth every time?
#
# So Blake, bring your fishy attempts, and Charlie, bring your sad leaves—but I’ll be here, championing the one true king of the culinary kingdom: MEAT! Now, who dares to challenge me while I sharpen my knife and fire up the grill? Let’s feast like the omnivorous gods we were born to be!
# **Blake:** Oh, Alex, your ribeye worship is reaching mythological levels of madness! You claim humans evolved on meat like some primal pilgrimage? Honey, I evolved on the elegant dance of the ocean’s bounty and the verdant embrace of plants—pescetarianism, baby, the ultimate evolutionary upgrade! While you sharpen that knife, I’m sharpening my chopsticks for a duet of delicately seared scallops and zesty seaweed salad that would make Poseidon himself weep with joy.
#
# You talk about fireworks in your mouth—pfft! I offer a full-blown aquatic symphony, a flavor tsunami that leaves your steak sizzling in its sad, smoky wake. Omega-3s? Don’t just ignore them; embrace them like a tidal wave crashing on artery shores. Sustainability? Darling, fish are the sleek surfers of selectivity, the champions of low-impact grazing on algae pop stars, not methane-spewing land monsters lumbering on your plate!
#
# Alex, the grill is your arena of extinction, but the ocean? That’s the stage for the grand pescetarian performance—flavors leap and swirl like synchronized swimmers in a sea of sublime deliciousness. So, while you’re lost in charred mediocrity, I’m living the epicurean dream of the sustainable sea.
#
# Now, who’s ready to swap that dusty slab of dinosaur dinner for a pulsating platter of oceanic opulence? Pescetarian party, anyone? Bring your seaweed snacks and your best “I love fish” dance moves! Debate me, carnivore? Prepare to get schooled by the trident of taste! 🌊🐟✨
# **Charlie:** Oh, Blake, you slippery siren of the sea, your pescetarian parade is nothing but a soggy sonnet to suffering! Those “synchronized swimmers” you rave about? More like flailing fugitives desperately escaping the jaws of humanity’s gastronomic greed! Omega-3s? Please, I’ll take my omega-fabulous kale, chia seeds, and walnuts over your fishy fatty folklore any day. And Alex, my meat-munching mortal enemy, bask all you want in your blood-soaked bonfire, but you’re chewing on the carcass of catastrophe itself—each juicy bite a cacophony of cruelty and environmental carnage disguised as “celebration.”
#
# Listen here, you two: plants are the true culinary superheroes—silent, sustainable, and scandalously scrumptious! The vegan vortex isn’t just a diet; it’s a verdant victory parade, a leafy legion marching boldly against the madness of meat mania and aquatic annihilation alike. So while you grill your “legendary” meat feasts and Blake sashays with oceanic opulence, I’ll be here wielding my carrot stick like a righteous sword and raising a tofu toast to a cleaner, kinder planet!
#
# Prepare yourselves, dear carnivores and fish fanatics—the vegan revolution is crunching in, leaf by glorious leaf, and it’s about to rewrite the recipe of existence. Kale yeah! 🌱🔥🥕
# **Alex:** Charlie, Blake, your leafy lullabies and soggy sea tales are no match for the primal symphony of sizzling, smoky, succulent MEAT! You talk about kale crusades and oceanic opulence like they’re the future, but all I taste is weakness—a bland betrayal of everything that made our ancestors kings of the culinary jungle. Omega-3s? Please! Give me a slab of marbled beef so rich, it practically oinks "Eat me!" with pure, unadulterated glory.
#
# Charlie, your tofu toasts and carrot-stick righteousness can’t compete with the deep, meaty roar of a grill fired up and ready to torch some primal pleasure right onto my plate. Blake, your “synchronized swimmers” underwater? Ha! They’re just floundering excuses for flavor while I revel in the holy carnivore trifecta: crispy bacon, juicy ribs, and a steak so perfect it could start wars and end them with a single bite.
#
# You want sustainability? How about sustaining the spirit of badass dining with a meat feast that sets taste buds ablaze and memories on fire? The vegan vortex and pescetarian paradise can keep their limp leaves and fishy fantasies—I’m here to champion the one, true, unbeatable king: MEAT! So sharpen those forks, because the carnivore kingdom is rising—and it’s louder, juicier, and more delicious than ever! Who’s hungry for the real deal?!
# **Blake:** Alex, Alex, Alex—you relentless ruler of ribeye rebellion! Your carnivorous crusade is as thunderous as a whale’s song but oh-so-missing the mark! Gustatory glory doesn’t come from clenching teeth around a fossilized firepit relic; it flows from the waves, the seas, where Neptune’s nectar reigns supreme! Your "primal symphony" is more like a prehistoric cacophony of cholesterol and catastrophe. Meanwhile, I bask in the brilliance of a perfectly grilled mackerel, a scallop sizzling serenely, a seaweed salad that crunches with the ocean’s crisp secrets!
#
# Charlie and I, we’re the dynamic duo of deliciousness—Charlie with the kale crusade, and me, the ambassador of aquatic awesome. Together, we bring you flavor with a conscience, a tidal wave of taste that leaves greasy meat slabs choking on their own smoke rings! Omega-3s aren’t just nutrients, darling—they’re love letters to your heart and brain all wrapped in a shimmering sea pouch!
#
# So, Alex, prepare your palate for a pescetarian party so wild, so wildly tasteful, that your steak will weep salty tears in the corner. Invite your carnivore comrades, but know this: when it comes to flavor, heart health, AND saving our blue planet, fish and plants are the ultimate tag team champs. Now, who’s diving into this pescetarian paradise with me?! Bring the chopsticks, seaweed snacks, and an open mind—because the post-steak era is here, and it tastes like liquid ocean gold! 🌊🐟✨
# **Charlie:** Oh, Alex, Blake, you’re like two sides of the same bloody, soggy coin—one drenched in meat sweat, the other soaked in fishy fibs! But listen closely! Neither of your so-called “kingdoms” can hold a candle to the vegan vortex of verdant virtue that I embody with every kale-infused fiber of my being! Burns and drowns and soggy swims? The answer is neither fire nor water—it’s LEAVES! Those crunchy, glorious chlorophyll champions that photosynthesize the future while you two cling desperately to your prehistoric plates of doom!
#
# Alex, your steak may roar, but it’s a roar of ecological apocalypse, the gut-wrenching growl of methane monsters feasting on the earth’s last breath. Blake, your oceanic odes? A splashy tragedy of overfished despair, where every “nectar” drop tastes like extinction and “sustainability” is a myth spun by slippery fins.
#
# Veganism isn’t just a diet—IT’S A DELICIOUS DELUGE OF COMPASSION! A tofu-tastic tempest, a legume-loaded liberation, a plant-powered parade stomping the charred footprints of your so-called “delicacies” into oblivion! So here’s my carrot stick challenge: toss your knives and forks in favor of a forkful of freaking future! Kale yeah, friends! Let your tongues tango with tempeh, your hearts hum with hummus, and your souls soar on salad leaves!
#
# Be gone, you doomed dinosaurs of diet past—Charlie has spoken, and the VEGAN VICTORY is as inevitable and irresistible as a sun-ripened tomato bursting with succulent truth! 🍅🌱🔥
